# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('photo_2024-05-04_15-13-27.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='BrBG', interpolation='bicubic')
plt.xticks([]), plt.yticks([])  # Hide tick values on X and Y axis
plt.show()
